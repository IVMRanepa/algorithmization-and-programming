# %% [markdown]
# <a href="https://colab.research.google.com/github/IVMRanepa/algorithmization-and-programming/blob/main/Algorithms_as_a_technology.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [Основы Python](https://fullstacker.ru/python-base)
#
# [Изучаем оператор if else Python](https://www.internet-technologies.ru/articles/operator-python-if-else.html)
#
# [Условный оператор if...else в Python](https://codechick.io/tutorials/python/if-elif-else)
#
# [Множественное ветвление: if-elif-else](https://younglinux.info/python/elif)

# %% [markdown]
# Пройдите тест по теме лекции  в данном google colaboratory или по [ссылке](https://forms.gle/8SohkuEND8dHANbZ7)

# %%
# %%html
# <iframe src="https://docs.google.com/forms/d/e/1FAIpQLSdnuKO-Ye6Tnh-B8Cn_YyyAYgI_B-2wpr1yP9ba7SJv1ffpwA/viewform?embedded=true" width="640" height="415" frameborder="0" marginheight="0" marginwidth="0">Загрузка…</iframe>
# Out:
# <iframe src="https://docs.google.com/forms/d/e/1FAIpQLSdnuKO-Ye6Tnh-B8Cn_YyyAYgI_B-2wpr1yP9ba7SJv1ffpwA/viewform?embedded=true" width="640" height="415" frameborder="0" marginheight="0" marginwidth="0">Загрузка…</iframe>

# %%
# Вставить таблицу с результатами
# %%html

# %% [markdown]
# # **Реализуйте в Python 3 блок схемы алгоритмов предложенные ниже**

# %% [markdown]
# # **Блок-схема обмена значениями**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Текст программы на «псевдоязыке»:**
#
# ввод a,b
#
# c=a
#
# a=b
#
# b=c
#
# вывод a,b

# %%
# Перестановка местами двух чисел с использованием кортежа
# (a,b)=input('Введите исходные значения (a, b) через запятую: ')
# (a,b) = (b,a)
# print 'Новое значение а: ',a,'\n','Новое значение b: ',b

# %% [markdown]
# # **Блок-схема о налоге**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Текст программы на «псевдоязыке»:
#
# ввод oklad,procent
#
# nalog=oklad* procent/100
#
# summa=oklad­ nalog
#
# вывод summa,nalog

# %%
# oklad=input("Оклад: ")

# procent=input("% налога: ") nalog=oklad*procent/100.0 summa=oklad­nalog

# print "Сумма на руки: ",summa
# print "Налог: ",nalog
# Если здесь все числа использовать как целые, то результат может получиться неверным.
# Поэтому одно из чисел нужно ввести как вещественное (с десятичной точкой).
# Именно поэтому деление делается не на 100, а на 100.0.

# %% [markdown]
# Используя данные таблицы
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# определить общую стоимость обеда в столовой. Определить, во сколько раз возрастёт стоимость обеда, если цена котлеты увеличится вдвое.

# %% [markdown]
# # **Блок-схема задачи об обеде**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Текст программы на «псевдоязыке»:
#
# ввод a,b,c,d
#
# S1=a,b,c,d
#
# S2=S1+b
#
# res=S2/S1
#
# вывод S1,res

# %%
# В программе на Python разумно будет использовать кортеж :

# t=(a,b,c,d)=input('Введите значения через запятую: ')
# S1=sum(t)
# S2=S1+b
# res=S2/S1
# print 'Начальная стоимость:',S1,'\n','Увеличение, раз:',res
